# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
silver = pd.read_excel("C:/Users/Lex/Desktop/Laser_correct_data/silver_data.xlsx")
al_ocside = pd.read_excel('C:/Users/Lex/Desktop/Laser_correct_data/al2o3_data.xlsx')
fe_ocside = pd.read_excel('C:/Users/Lex/Desktop/Laser_correct_data/fe2o3_data.xlsx')
glass = pd.read_excel('C:/Users/Lex/Desktop/Laser_correct_data/glass_bk7_data.xlsx')
air = pd.read_excel('C:/Users/Lex/Desktop/Laser_correct_data/air_data.xlsx')
al_ocside['k'] = 0
air['k'] = 0

# %%
plt.plot(al_ocside['Wavelength, µm'][al_ocside['Wavelength, µm'] < 0.5], al_ocside['n'][al_ocside['Wavelength, µm'] < 0.5], label='Aluminium diocside')
plt.plot(fe_ocside['Wavelength, µm'][fe_ocside['Wavelength, µm'] < 0.5], fe_ocside['n'][fe_ocside['Wavelength, µm'] < 0.5], label='Ferum diocside')
plt.xlabel('Wavelength, µm')
plt.ylabel('Refractive index')
plt.legend()

# %%
plt.plot(al_ocside['Wavelength, µm'][al_ocside['Wavelength, µm'] < 0.5], al_ocside['n'][al_ocside['Wavelength, µm'] < 0.5], label='Aluminium diocside')
plt.xlabel('Wavelength, µm')
plt.ylabel('Refractive index')
plt.legend()

# %%
plt.plot(fe_ocside['Wavelength, µm'][fe_ocside['Wavelength, µm'] < 0.5], fe_ocside['n'][fe_ocside['Wavelength, µm'] < 0.5], label='Ferum diocside')
plt.xlabel('Wavelength, µm')
plt.ylabel('Refractive index')
plt.legend()
